# %%
import urllib2
from bs4 import BeautifulSoup

# %%
path = 'https://www.privateproperty.co.za/for-sale/gauteng/pretoria/pretoria-east/991?page=1'
page = urllib2.urlopen(path)

# %%
soup = BeautifulSoup(page, 'html.parser')

# %%
name_box = soup.findAll('div', attrs={'class': 'infoHolder'})

# %%
name_box
# Out:
# [<div class="infoHolder">\n<div class="title">Townhouse in Equestria</div>\n<div class="priceDescription">R 749 000</div>\n<div class="priceAdditionalDescriptor"></div>\n<div class="features row">\n<div class="number">2</div>\n<div class="icon bedroom"></div>\n<div class="number">1</div>\n<div class="icon bathroom"></div>\n<div class="number">1</div>\n<div class="icon garage"></div>\n<div class="uspSpacer"></div>\n<div class="usp">\n<div class="tick"></div>\r\n                        Access Gate\r\n                    </div>\n<div class="usp">\n<div class="tick"></div>\r\n                        Security Post\r\n                    </div>\n<div class="usp">\n<div class="tick"></div>\r\n                        BIC\r\n                    </div>\n<div class="usp">\n<div class="tick"></div>\r\n                        Paving\r\n                    </div>\n</div>\n<div class="address">Belle Monte 21 Griffiths Road</div>\n<div class="bankOfficeOrPrivateSeller">\n<div class="link">\n<img cla
# ...
